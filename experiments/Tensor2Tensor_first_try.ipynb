# %% [markdown]
# # Tensor2Tensor translation
# First try using the deep learning framework for translation tasks using the transformer architecture.

# %% [markdown]
# <img style="width: 400px;" src="../images/transformer.png" />

# %%
import linecache
import os
import sys

import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plt

# %%
def show_sample(fp, src_ext=".src", tgt_ext=".tgt", lines=[3,21,80,99]):
    linecache.clearcache()
    for l in lines:
        print("LINE: {} \nSOURCE:    {} \nTARGET:     {}\n".format(l, 
                                                                   linecache.getline(fp+src_ext, l), 
                                                                   linecache.getline(fp+tgt_ext, l)))

# %%
django_fp = "../datasets/django/all"
show_sample(django_fp, src_ext=".desc", tgt_ext=".code", lines=[13,14])
# Out:
# LINE: 13
# SOURCE:      define the function get_cache with backend and dictionary pair of elements kwargs as arguments.
#
# TARGET:         def get_cache ( backend , ** kwargs ) :
#
#
# LINE: 14
# SOURCE:      call the function warnings.warn with string "'get_cache' is deprecated in favor of 'caches'.", RemovedInDjango19Warning,
#
# TARGET:      warnings . warn ( "'get_cache' is deprecated in favor of 'caches'." ,  RemovedInDjango19Warning , stacklevel = 2 )

# %% [markdown]
# ### Dataset and train / test split
# Copy the full dataset to the temp folder. We then split the data into a training and testing set at around 90% / 10%

# %%
dirName = "temp"
 
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  temp  Created

# %%
inputs_train_fp = "temp/inputs.train.txt"
targets_train_fp = "temp/targets.train.txt"
inputs_test_fp = "temp/inputs.eval.txt"
targets_test_fp = "temp/targets.eval.txt"

# %%
train_ratio = 0.9 # this means 90% of the data will be used for training, thus 10% for testing
num_samples = sum(1 for line in open(django_fp + ".desc"))
train_cutoff = int(num_samples * train_ratio)

line_nums = np.arange(num_samples)
np.random.shuffle(line_nums)

train_lines = line_nums[:train_cutoff]
test_lines = line_nums[train_cutoff:]

# %% [markdown]
# ##### Train split for .desc and .code

# %%
with open(inputs_train_fp, "w") as out:
    for l in train_lines:
        src = linecache.getline(django_fp + ".desc", l)
        out.write(src)

# %%
with open(targets_train_fp, "w") as out:
    for l in train_lines:
        src = linecache.getline(django_fp + ".code", l)
        out.write(src)

# %% [markdown]
# ##### Test split for .desc and .code

# %%
with open(inputs_test_fp, "w") as out:
    for l in test_lines:
        src = linecache.getline(django_fp + ".desc", l)
        out.write(src)

# %%
with open(targets_test_fp, "w") as out:
    for l in test_lines:
        src = linecache.getline(django_fp + ".code", l)
        out.write(src)

# %% [markdown]
# ## Generating the data
# Tensor2Tensor uses Problems to define the datainput to the model. We arer currently using a facility provided by the library to generate a problem from input and target files.

# %%
# !pwd
# !ls
# Out:
# /my_shared/experiments
# Tensor2Tensor_first_try.ipynb  datasets.ipynb  retrieval.ipynb	temp

# %%
# !t2t-datagen --tmp_dir=./temp --problem=text2text_tmpdir
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W0819 13:08:31.380589 139897936963328 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0819 13:08:32.659285 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0819 13:08:34.456824 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/rl/gym_utils.py:219: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0819 13:08:34.460567 139897936963328 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0819 13:08:34.460705 139897936963328 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:27: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0819 13:08:34.460793 139897936963328 deprecation_wrapper.py:119] From /usr/local/bin/t2t-datagen:28: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0819 13:08:34.463274 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/bin/t2t_datagen.py:200: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W0819 13:08:34.463382 139897936963328 t2t_datagen.py:202] It is strongly recommended to specify --data_dir. Data will be written to default data_dir=/tmp.
# W0819 13:08:34.463727 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/bin/t2t_datagen.py:204: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# I0819 13:08:34.463831 139897936963328 t2t_datagen.py:207] Generating problems:
#     text2text:
#       * text2text_tmpdir
# W0819 13:08:34.463916 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/bin/t2t_datagen.py:156: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# I0819 13:08:34.464565 139897936963328 t2t_datagen.py:280] Generating data for text2text_tmpdir.
# W0819 13:08:34.464910 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/generator_utils.py:343: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# I0819 13:08:34.465034 139897936963328 generator_utils.py:349] Generating vocab file: /tmp/vocab.text2text_tmpdir.32768.subwords
# W0819 13:08:34.465134 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/text_problems.py:610: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# I0819 13:08:35.237834 139897936963328 text_encoder.py:722] Trying min_count 500
# I0819 13:08:35.256664 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:35.673476 139897936963328 text_encoder.py:866] vocab_size = 965
# I0819 13:08:35.673841 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:35.967427 139897936963328 text_encoder.py:866] vocab_size = 508
# I0819 13:08:35.967631 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:36.218928 139897936963328 text_encoder.py:866] vocab_size = 541
# I0819 13:08:36.219144 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:36.458728 139897936963328 text_encoder.py:866] vocab_size = 533
# I0819 13:08:36.462643 139897936963328 text_encoder.py:722] Trying min_count 250
# I0819 13:08:36.465713 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:36.911578 139897936963328 text_encoder.py:866] vocab_size = 1543
# I0819 13:08:36.911798 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:37.133840 139897936963328 text_encoder.py:866] vocab_size = 711
# I0819 13:08:37.134063 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:37.395840 139897936963328 text_encoder.py:866] vocab_size = 770
# I0819 13:08:37.396164 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:37.713300 139897936963328 text_encoder.py:866] vocab_size = 754
# I0819 13:08:37.718107 139897936963328 text_encoder.py:722] Trying min_count 125
# I0819 13:08:37.721581 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:38.116696 139897936963328 text_encoder.py:866] vocab_size = 2392
# I0819 13:08:38.117123 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:38.330088 139897936963328 text_encoder.py:866] vocab_size = 1068
# I0819 13:08:38.330311 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:38.555809 139897936963328 text_encoder.py:866] vocab_size = 1124
# I0819 13:08:38.556070 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:38.770539 139897936963328 text_encoder.py:866] vocab_size = 1115
# I0819 13:08:38.773955 139897936963328 text_encoder.py:722] Trying min_count 62
# I0819 13:08:38.776998 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:39.176549 139897936963328 text_encoder.py:866] vocab_size = 3728
# I0819 13:08:39.176832 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:39.402698 139897936963328 text_encoder.py:866] vocab_size = 1565
# I0819 13:08:39.402932 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:39.637024 139897936963328 text_encoder.py:866] vocab_size = 1648
# I0819 13:08:39.637243 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:39.858366 139897936963328 text_encoder.py:866] vocab_size = 1633
# I0819 13:08:39.862725 139897936963328 text_encoder.py:722] Trying min_count 31
# I0819 13:08:39.866750 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:40.244116 139897936963328 text_encoder.py:866] vocab_size = 5606
# I0819 13:08:40.244310 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:40.424090 139897936963328 text_encoder.py:866] vocab_size = 2259
# I0819 13:08:40.424336 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:40.650513 139897936963328 text_encoder.py:866] vocab_size = 2354
# I0819 13:08:40.650731 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:40.839161 139897936963328 text_encoder.py:866] vocab_size = 2330
# I0819 13:08:40.841659 139897936963328 text_encoder.py:722] Trying min_count 15
# I0819 13:08:40.844401 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:41.228642 139897936963328 text_encoder.py:866] vocab_size = 8353
# I0819 13:08:41.228844 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:41.395264 139897936963328 text_encoder.py:866] vocab_size = 3205
# I0819 13:08:41.395498 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:41.563670 139897936963328 text_encoder.py:866] vocab_size = 3353
# I0819 13:08:41.563889 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:41.730688 139897936963328 text_encoder.py:866] vocab_size = 3324
# I0819 13:08:41.732908 139897936963328 text_encoder.py:722] Trying min_count 7
# I0819 13:08:41.735652 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:42.280623 139897936963328 text_encoder.py:866] vocab_size = 12467
# I0819 13:08:42.280842 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:42.474373 139897936963328 text_encoder.py:866] vocab_size = 4399
# I0819 13:08:42.474606 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:42.708752 139897936963328 text_encoder.py:866] vocab_size = 4618
# I0819 13:08:42.708979 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:42.897279 139897936963328 text_encoder.py:866] vocab_size = 4564
# I0819 13:08:42.899871 139897936963328 text_encoder.py:722] Trying min_count 3
# I0819 13:08:42.903280 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:43.434096 139897936963328 text_encoder.py:866] vocab_size = 18159
# I0819 13:08:43.434339 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:43.640927 139897936963328 text_encoder.py:866] vocab_size = 6066
# I0819 13:08:43.641201 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:43.839031 139897936963328 text_encoder.py:866] vocab_size = 6284
# I0819 13:08:43.839275 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:44.027545 139897936963328 text_encoder.py:866] vocab_size = 6216
# I0819 13:08:44.029986 139897936963328 text_encoder.py:722] Trying min_count 1
# I0819 13:08:44.033656 139897936963328 text_encoder.py:802] Iteration 0
# I0819 13:08:44.695388 139897936963328 text_encoder.py:866] vocab_size = 26591
# I0819 13:08:44.695591 139897936963328 text_encoder.py:802] Iteration 1
# I0819 13:08:44.846405 139897936963328 text_encoder.py:866] vocab_size = 7729
# I0819 13:08:44.846639 139897936963328 text_encoder.py:802] Iteration 2
# I0819 13:08:44.973711 139897936963328 text_encoder.py:866] vocab_size = 7729
# I0819 13:08:44.973948 139897936963328 text_encoder.py:802] Iteration 3
# I0819 13:08:45.126042 139897936963328 text_encoder.py:866] vocab_size = 7729
# W0819 13:08:45.163362 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/generator_utils.py:164: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# I0819 13:08:45.241680 139897936963328 generator_utils.py:170] Generating case 0.
# W0819 13:08:48.140474 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/generator_utils.py:183: The name tf.gfile.Rename is deprecated. Please use tf.io.gfile.rename instead.
#
# I0819 13:08:48.144754 139897936963328 generator_utils.py:193] Generated 16923 Examples
# I0819 13:08:48.145422 139897936963328 generator_utils.py:344] Found vocab file: /tmp/vocab.text2text_tmpdir.32768.subwords
# I0819 13:08:48.189845 139897936963328 generator_utils.py:170] Generating case 0.
# I0819 13:08:48.538261 139897936963328 generator_utils.py:193] Generated 1881 Examples
# I0819 13:08:48.539574 139897936963328 generator_utils.py:527] Shuffling data...
# W0819 13:08:48.539712 139897936963328 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/generator_utils.py:469: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0819 13:08:48.544435 139897936963328 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/generator_utils.py:513: The name tf.gfile.Remove is deprecated. Please use tf.io.gfile.remove instead.
#
# I0819 13:08:48.840376 139897936963328 generator_utils.py:530] Data shuffled.

# %%
# !t2t-trainer --problem=text2text_tmpdir \
             --hparams_set=transformer_base \
             --hparams='batch_size=1024' \
             --model=transformer \
             --data_dir=/tmp \
             --output_dir=./temp/model
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W0819 13:21:28.144207 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0819 13:21:28.625369 140450289841920 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0819 13:21:30.457783 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/adafactor.py:27: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0819 13:21:30.458249 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/multistep_optimizer.py:32: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0819 13:21:30.486831 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/mesh_tensorflow/ops.py:4237: The name tf.train.CheckpointSaverListener is deprecated. Please use tf.estimator.CheckpointSaverListener instead.
#
# W0819 13:21:30.487151 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/mesh_tensorflow/ops.py:4260: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0819 13:21:30.545042 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/rl/gym_utils.py:219: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0819 13:21:30.725220 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:109: The name tf.OptimizerOptions is deprecated. Please use tf.compat.v1.OptimizerOptions instead.
#
# W0819 13:21:31.583921 140450289841920 deprecation_wrapper.py:119] From /usr/local/bin/t2t-trainer:32: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0819 13:21:31.584667 140450289841920 deprecation_wrapper.py:119] From /usr/local/bin/t2t-trainer:32: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0819 13:21:31.584929 140450289841920 deprecation_wrapper.py:119] From /usr/local/bin/t2t-trainer:33: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0819 13:21:31.586153 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/hparams_lib.py:49: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0819 13:21:31.589554 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:780: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0819 13:21:31.591602 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:121: The name tf.GraphOptions is deprecated. Please use tf.compat.v1.GraphOptions instead.
#
# W0819 13:21:31.591927 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:127: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0819 13:21:31.592163 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:240: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# I0819 13:21:31.592411 140450289841920 trainer_lib.py:263] Configuring DataParallelism to replicate the model.
# I0819 13:21:31.592527 140450289841920 devices.py:76] schedule=continuous_train_and_eval
# I0819 13:21:31.592622 140450289841920 devices.py:77] worker_gpu=1
# I0819 13:21:31.592712 140450289841920 devices.py:78] sync=False
# W0819 13:21:31.592837 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/devices.py:139: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# W0819 13:21:31.592936 140450289841920 devices.py:141] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# I0819 13:21:31.593420 140450289841920 devices.py:170] datashard_devices: ['gpu:0']
# I0819 13:21:31.593538 140450289841920 devices.py:171] caching_devices: None
# I0819 13:21:31.593906 140450289841920 devices.py:172] ps_devices: ['gpu:0']
# W0819 13:21:31.594190 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/text_encoder.py:940: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
# I0819 13:21:31.644086 140450289841920 estimator.py:209] Using config: {'_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbcdee5a470>, '_keep_checkpoint_every_n_hours': 10000, '_device_fn': None, '_environment': 'local', '_is_chief': True, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# isolate_session_state: true
# , '_model_dir': './temp/model', '_save_checkpoints_steps': 1000, '_experimental_max_worker_delay_secs': None, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7fbcdee5a4a8>, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_task_type': None, 't2t_device_info': {'num_async_replicas': 1}, '_save_summary_steps': 100, '_master': '', 'use_tpu': False, '_eval_distribute': None, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_keep_checkpoint_max': 20, '_task_id': 0, '_num_worker_replicas': 0, '_tf_random_seed': None, '_protocol': None}
# W0819 13:21:31.644440 140450289841920 model_fn.py:630] Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7fbcdee18048>) includes params argument, but params are not passed to Estimator.
# W0819 13:21:31.650971 140450289841920 trainer_lib.py:724] ValidationMonitor only works with --schedule=train_and_evaluate
# W0819 13:21:31.652801 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/bin/t2t_trainer.py:317: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# I0819 13:21:31.660513 140450289841920 estimator_training.py:186] Not using Distribute Coordinator.
# I0819 13:21:31.660809 140450289841920 training.py:612] Running training and evaluation locally (non-distributed).
# I0819 13:21:31.661168 140450289841920 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# W0819 13:21:31.669235 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# I0819 13:21:31.682285 140450289841920 problem.py:644] Reading data files from /tmp/text2text_tmpdir-train*
# I0819 13:21:31.685592 140450289841920 problem.py:670] partition: 0 num_data_files: 100
# W0819 13:21:31.689144 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/data_generators/problem.py:680: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W0819 13:21:31.754652 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/data_reader.py:275: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0819 13:21:31.766926 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/data_reader.py:37: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0819 13:21:31.810991 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/data/experimental/ops/grouping.py:193: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0819 13:21:31.864986 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/data_reader.py:231: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0819 13:21:31.874017 140450289841920 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/data_reader.py:233: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# I0819 13:21:31.921264 140450289841920 estimator.py:1145] Calling model_fn.
# I0819 13:21:31.932029 140450289841920 t2t_model.py:2172] Setting T2TModel mode to 'train'
# W0819 13:21:31.989254 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/t2t_model.py:243: The name tf.summary.text is deprecated. Please use tf.compat.v1.summary.text instead.
#
# I0819 13:21:32.797448 140450289841920 api.py:255] Using variable initializer: uniform_unit_scaling
# I0819 13:21:33.378898 140450289841920 t2t_model.py:2172] Transforming feature 'inputs' with symbol_modality_7729_512.bottom
# I0819 13:21:33.511929 140450289841920 t2t_model.py:2172] Transforming feature 'targets' with symbol_modality_7729_512.targets_bottom
# I0819 13:21:33.522522 140450289841920 t2t_model.py:2172] Building model body
# W0819 13:21:33.596270 140450289841920 deprecation.py:506] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/models/transformer.py:93: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0819 13:21:33.636891 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:3106: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# W0819 13:21:34.020126 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_attention.py:1217: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# I0819 13:21:40.261476 140450289841920 t2t_model.py:2172] Transforming body output with symbol_modality_7729_512.top
# W0819 13:21:40.387196 140450289841920 deprecation_wrapper.py:119] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/learning_rate.py:107: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# I0819 13:21:40.388492 140450289841920 learning_rate.py:29] Base learning rate: 2.000000
# I0819 13:21:40.401365 140450289841920 optimize.py:327] Trainable Variables Total size: 48077312
# I0819 13:21:40.401644 140450289841920 optimize.py:327] Non-trainable variables Total size: 5
# I0819 13:21:40.401946 140450289841920 optimize.py:182] Using optimizer adam
# I0819 13:21:49.449776 140450289841920 estimator.py:1147] Done calling model_fn.
# I0819 13:21:49.450937 140450289841920 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0819 13:21:53.622741 140450289841920 monitored_session.py:240] Graph was finalized.
# 2019-08-19 13:21:53.624192: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-08-19 13:21:53.644084: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2592000000 Hz
# 2019-08-19 13:21:53.645951: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x146cb380 executing computations on platform Host. Devices:
# 2019-08-19 13:21:53.645997: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-19 13:21:54.126421: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_0/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_0 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_0/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_0/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_0/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_0/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_0/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_203 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_204 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_203 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_204 (VarIsInitializedOp)
#   save/AssignVariableOp_372 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_373 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_589 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.127530: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_1/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_1 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_1/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_1/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_1 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_1/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_1/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_1 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_205 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_206 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_1 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_205 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_206 (VarIsInitializedOp)
#   save/AssignVariableOp_374 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_375 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_590 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.128309: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_2/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_2 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_2/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_2/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_2/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_2/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_2 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_2/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_2/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_2 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_207 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_208 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_2 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_207 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_208 (VarIsInitializedOp)
#   save/AssignVariableOp_388 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_389 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_597 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.128900: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_3/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_3 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_3/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_3/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_3/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_3/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_3 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_3/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_3/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_3 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_209 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_210 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_3 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_209 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_210 (VarIsInitializedOp)
#   save/AssignVariableOp_390 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_391 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_598 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.129497: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_4/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_4 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_4/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_4/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_4/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_4/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_4 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_4/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_4/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_4 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_211 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_212 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_4 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_211 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_212 (VarIsInitializedOp)
#   save/AssignVariableOp_392 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_393 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_599 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.130019: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_5/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_5 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_5/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_5/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_5/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_5/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_5 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_5/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/symbol_modality_7729_512/shared/weights_5/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_5 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_213 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_214 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_5 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_213 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_214 (VarIsInitializedOp)
#   save/AssignVariableOp_394 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_395 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_600 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.130569: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# Fill: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# Add: CPU XLA_CPU
# Mul: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal/shape (Const)
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal/mean (Const)
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal/stddev (Const)
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal)
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal/mul (Mul)
#   transformer/symbol_modality_7729_512/shared/weights_6/Initializer/random_normal (Add)
#   transformer/symbol_modality_7729_512/shared/weights_6 (VarHandleOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_6/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_6/Assign (AssignVariableOp) /device:GPU:0
#   transformer/symbol_modality_7729_512/shared/weights_6/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_6/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_6 (ReadVariableOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/symbol_modality_7729_512/shared/weights_6/Adam/Assign (AssignVariableOp) /device:GPU:0
# ...
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Initializer/random_uniform/RandomUniform (RandomUniform)
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Initializer/random_uniform/sub (Sub)
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Initializer/random_uniform/mul (Mul)
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Initializer/random_uniform (Add)
#   transformer/body/decoder/layer_5/ffn/conv2/kernel (VarHandleOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Assign (AssignVariableOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/kernel/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_197/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_197 (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/kernel/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/body/decoder/layer_5/ffn/conv2/kernel/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_197 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_597 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_598 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_197 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_597 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_598 (VarIsInitializedOp)
#   save/AssignVariableOp_200 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_201 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_503 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.337318: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/body/decoder/layer_5/ffn/conv2/bias/Initializer/zeros (Const)
#   transformer/body/decoder/layer_5/ffn/conv2/bias (VarHandleOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/bias/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/bias/Assign (AssignVariableOp) /device:GPU:0
#   transformer/body/decoder/layer_5/ffn/conv2/bias/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_198/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_198 (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_5/ffn/conv2/bias/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/body/decoder/layer_5/ffn/conv2/bias/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_198 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_599 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_600 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_198 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_599 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_600 (VarIsInitializedOp)
#   save/AssignVariableOp_198 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_199 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_502 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.337915: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Initializer/ones (Const)
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale (VarHandleOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Assign (AssignVariableOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_199/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_199 (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_scale/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_199 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_601 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_602 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_199 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_601 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_602 (VarIsInitializedOp)
#   save/AssignVariableOp_220 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_221 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_513 (AssignVariableOp) /device:GPU:0
#
# 2019-08-19 13:21:54.338406: W tensorflow/core/common_runtime/colocation_graph.cc:1016] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0
#   /job:localhost/replica:0/task:0/device:XLA_CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU, XLA_CPU] possible_devices_=[]
# ResourceApplyAdam: CPU XLA_CPU
# ReadVariableOp: CPU XLA_CPU
# AssignVariableOp: CPU XLA_CPU
# VarIsInitializedOp: CPU XLA_CPU
# VarHandleOp: CPU XLA_CPU
# Const: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Initializer/zeros (Const)
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias (VarHandleOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Assign (AssignVariableOp) /device:GPU:0
#   transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   Read_200/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/ReadVariableOp_200 (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam_1 (VarHandleOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam_1/IsInitialized/VarIsInitializedOp (VarIsInitializedOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam_1/Assign (AssignVariableOp) /device:GPU:0
#   training/transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/Adam_1/Read/ReadVariableOp (ReadVariableOp) /device:GPU:0
#   training/train/update_transformer/body/decoder/layer_prepostprocess/layer_norm/layer_norm_bias/ResourceApplyAdam (ResourceApplyAdam) /device:GPU:0
#   report_uninitialized_variables/VarIsInitializedOp_200 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_603 (VarIsInitializedOp)
#   report_uninitialized_variables/VarIsInitializedOp_604 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_200 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_603 (VarIsInitializedOp)
#   report_uninitialized_variables_1/VarIsInitializedOp_604 (VarIsInitializedOp)
#   save/AssignVariableOp_218 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_219 (AssignVariableOp) /device:GPU:0
#   save/AssignVariableOp_512 (AssignVariableOp) /device:GPU:0
# 2019-08-19 13:21:55.911464: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# I0819 13:21:57.542656 140450289841920 session_manager.py:500] Running local_init_op.
# I0819 13:21:57.777920 140450289841920 session_manager.py:502] Done running local_init_op.
# I0819 13:22:07.965782 140450289841920 basic_session_run_hooks.py:606] Saving checkpoints for 0 into ./temp/model/model.ckpt.
# 2019-08-19 13:22:35.223431: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:111] Filling up shuffle buffer (this may take a while): 117 of 512
# 2019-08-19 13:22:45.015565: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:111] Filling up shuffle buffer (this may take a while): 276 of 512
# 2019-08-19 13:22:55.033494: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:111] Filling up shuffle buffer (this may take a while): 432 of 512
# 2019-08-19 13:23:02.409222: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:162] Shuffle buffer filled.
# I0819 13:23:08.089487 140450289841920 basic_session_run_hooks.py:262] loss = 8.330775, step = 1
# Killed
